# %%
# Library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Warnings
import warnings
warnings.filterwarnings(action='ignore')

# %%
# Data Loading
data = pd.read_csv('./data/DAILY_DATA.csv')
data = data[['date', 'USD', 'CAD', 'CHF', 'GBP', 'EUR', 'JPY(100)']].set_index('date')

# %%
data
# Out:
#                USD      CAD      CHF      GBP      EUR  JPY(100)
# date
# 2010-01-04  1161.0  1110.15  1128.17  1883.46  1673.46   1256.50
# 2010-01-05  1147.3  1109.76  1122.31  1860.44  1665.97   1250.96
# 2010-01-06  1141.4  1101.19  1106.67  1829.39  1643.96   1248.35
# 2010-01-07  1132.0  1102.69  1107.41  1822.54  1639.52   1232.35
# 2010-01-08  1134.1  1095.51  1095.46  1804.73  1621.38   1211.91
# ...            ...      ...      ...      ...      ...       ...
# 2020-01-10  1160.0   888.34  1192.13  1516.00  1288.47   1059.60
# 2020-01-13  1161.1   888.85  1192.89  1514.48  1290.74   1059.93
# 2020-01-14  1155.7   885.39  1190.52  1501.25  1286.93   1051.35
# 2020-01-15  1153.1   882.76  1191.96  1501.34  1283.11   1048.42
# 2020-01-16  1158.8   888.45  1202.32  1511.36  1292.24   1054.37
#
# [2485 rows x 6 columns]

# %%
# Data Shfit 생성    
cnt = ['USD', 'CAD', 'CHF', 'GBP', 'EUR', 'JPY(100)']
for step1 in cnt : 
    for step2 in range(1,6):
        data['{}_shift-{}'.format(step1,step2)] = data[step1].shift(step2)
data = data[5:]

# %%
data
# Out:
#                USD      CAD      CHF      GBP      EUR  JPY(100)  USD_shift-1  \
# date
# 2010-01-11  1121.3  1099.37  1106.62  1820.29  1633.47   1223.96       1134.1
# 2010-01-12  1123.3  1083.40  1102.44  1804.61  1625.56   1216.58       1121.3
# 2010-01-13  1127.0  1081.90  1103.78  1817.10  1628.85   1234.23       1123.3
# 2010-01-14  1123.1  1092.96  1106.10  1833.78  1634.41   1232.05       1127.0
# 2010-01-15  1122.2  1096.28  1101.50  1833.85  1627.16   1230.24       1123.1
# ...            ...      ...      ...      ...      ...       ...          ...
# 2020-01-10  1160.0   888.34  1192.13  1516.00  1288.47   1059.60       1174.1
# 2020-01-13  1161.1   888.85  1192.89  1514.48  1290.74   1059.93       1160.0
# 2020-01-14  1155.7   885.39  1190.52  1501.25  1286.93   1051.35       1161.1
# 2020-01-15  1153.1   882.76  1191.96  1501.34  1283.11   1048.42       1155.7
# 2020-01-16  1158.8   888.45  1202.32  1511.36  1292.24   1054.37       1153.1
#
#             USD_shift-2  USD_shift-3  USD_shift-4  ...  EUR_shift-1  \
# date                                               ...
# 2010-01-11       1132.0       1141.4       1147.3  ...      1621.38
# 2010-01-12       1134.1       1132.0       1141.4  ...      1633.47
# 2010-01-13       1121.3       1134.1       1132.0  ...      1625.56
# 2010-01-14       1123.3       1121.3       1134.1  ...      1628.85
# 2010-01-15       1127.0       1123.3       1121.3  ...      1634.41
# ...                 ...          ...          ...  ...          ...
# 2020-01-10       1165.3       1169.6       1162.7  ...      1304.25
# 2020-01-13       1174.1       1165.3       1169.6  ...      1288.47
# 2020-01-14       1160.0       1174.1       1165.3  ...      1290.74
# 2020-01-15       1161.1       1160.0       1174.1  ...      1286.93
# 2020-01-16       1155.7       1161.1       1160.0  ...      1283.11
#
#             EUR_shift-2  EUR_shift-3  EUR_shift-4  EUR_shift-5  \
# date
# 2010-01-11      1639.52      1643.96      1665.97      1673.46
# 2010-01-12      1621.38      1639.52      1643.96      1665.97
# 2010-01-13      1633.47      1621.38      1639.52      1643.96
# 2010-01-14      1625.56      1633.47      1621.38      1639.52
# 2010-01-15      1628.85      1625.56      1633.47      1621.38
# ...                 ...          ...          ...          ...
# 2020-01-10      1299.25      1309.54      1298.15      1292.66
# 2020-01-13      1304.25      1299.25      1309.54      1298.15
# 2020-01-14      1288.47      1304.25      1299.25      1309.54
# 2020-01-15      1290.74      1288.47      1304.25      1299.25
# 2020-01-16      1286.93      1290.74      1288.47      1304.25
#
#             JPY(100)_shift-1  JPY(100)_shift-2  JPY(100)_shift-3  \
# date
# 2010-01-11           1211.91           1232.35           1248.35
# 2010-01-12           1223.96           1211.91           1232.35
# 2010-01-13           1216.58           1223.96           1211.91
# 2010-01-14           1234.23           1216.58           1223.96
# 2010-01-15           1232.05           1234.23           1216.58
# ...                      ...               ...               ...
# 2020-01-10           1076.12           1074.95           1079.02
# 2020-01-13           1059.60           1076.12           1074.95
# 2020-01-14           1059.93           1059.60           1076.12
# 2020-01-15           1051.35           1059.93           1059.60
# 2020-01-16           1048.42           1051.35           1059.93
#
#             JPY(100)_shift-4  JPY(100)_shift-5
# date
# 2010-01-11           1250.96           1256.50
# 2010-01-12           1248.35           1250.96
# 2010-01-13           1232.35           1248.35
# 2010-01-14           1211.91           1232.35
# 2010-01-15           1223.96           1211.91
# ...                      ...               ...
# 2020-01-10           1078.42           1065.53
# 2020-01-13           1079.02           1078.42
# 2020-01-14           1074.95           1079.02
# 2020-01-15           1076.12           1074.95
# 2020-01-16           1059.60           1076.12
#
# [2480 rows x 36 columns]

# %%
# X, y
X = data[data.columns[6:]]
y = data[data.columns[0]]

# %%
# MinMaxScaler
from sklearn.preprocessing import MinMaxScaler
sc_X = MinMaxScaler()
X = sc_X.fit_transform(X)
sc_y = MinMaxScaler()
y = sc_y.fit_transform(y.values.reshape(-1,1))

# %%
# Train Validation Test Split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=1234)
X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size=0.2, random_state=1234)

# %%
# Data Size
print('Train Set Size : {:,} obs' .format(len(X_train)))
print('Valid Set Size : {:,} obs' .format(len(X_valid)))
print('Test Set Size : {:,} obs' .format(len(X_test)))
# Out:
# Train Set Size : 1,785 obs
# Valid Set Size : 447 obs
# Test Set Size : 248 obs

# %%
# Sklearn Linear Regression
from sklearn.linear_model import LinearRegression
reg = LinearRegression().fit(X_train, y_train)

# %%
# Score
print("Train Score : {}" .format(reg.score(X_train, y_train)))
print("Valid Score : {}" .format(reg.score(X_valid, y_valid)))
print("Test Score : {}" .format(reg.score(X_test, y_test)))
# Out:
# Train Score : 0.9814805149731488
# Valid Score : 0.9790272022386453
# Test Score : 0.9850990346784153

# %%
# RMSE
from sklearn.metrics import mean_squared_error
pred_train = reg.predict(X_train)
print("Train rmse : {}" .format(mean_squared_error(y_train, pred_train)**0.5))
pred_valid = reg.predict(X_valid)
print("Valid rmse : {}" .format(mean_squared_error(y_valid, pred_valid)**0.5))
pred_test = reg.predict(X_test)
print("Test rmse : {}" .format(mean_squared_error(y_test, pred_test)**0.5))
# Out:
# Train rmse : 0.023793009662187725
# Valid rmse : 0.02582773239118246
# Test rmse : 0.02186607664754281

# %%
# Data Reverse
y_test_origin = sc_y.inverse_transform(y_test)
y_pred_origin = sc_y.inverse_transform(pred_test)

# Test Data
test = np.array([y_test_origin.reshape(-1), y_pred_origin.reshape(-1)]).transpose()
test = pd.DataFrame(test, columns = ['y_test', 'y_pred'])

# %%
# Pred vs True Visualization
plt.figure(figsize = (16,6))
sns.lineplot(data = test, linewidth = 2.5)
plt.show()
