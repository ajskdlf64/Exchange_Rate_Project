# %%
# Library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Warnings
import warnings
warnings.filterwarnings(action='ignore')

# %%
# Data Loading
data = pd.read_csv('./data/DAILY_DATA.csv')
data = data[['date', 'USD', 'CAD', 'CHF', 'GBP', 'EUR', 'JPY(100)']].set_index('date')

# %%
data
# Out:
#                USD      CAD      CHF      GBP      EUR  JPY(100)
# date
# 2010-01-04  1161.0  1110.15  1128.17  1883.46  1673.46   1256.50
# 2010-01-05  1147.3  1109.76  1122.31  1860.44  1665.97   1250.96
# 2010-01-06  1141.4  1101.19  1106.67  1829.39  1643.96   1248.35
# 2010-01-07  1132.0  1102.69  1107.41  1822.54  1639.52   1232.35
# 2010-01-08  1134.1  1095.51  1095.46  1804.73  1621.38   1211.91
# ...            ...      ...      ...      ...      ...       ...
# 2020-01-10  1160.0   888.34  1192.13  1516.00  1288.47   1059.60
# 2020-01-13  1161.1   888.85  1192.89  1514.48  1290.74   1059.93
# 2020-01-14  1155.7   885.39  1190.52  1501.25  1286.93   1051.35
# 2020-01-15  1153.1   882.76  1191.96  1501.34  1283.11   1048.42
# 2020-01-16  1158.8   888.45  1202.32  1511.36  1292.24   1054.37
#
# [2485 rows x 6 columns]

# %%
# Data Shfit 생성    
cnt = ['USD', 'CAD', 'CHF', 'GBP', 'EUR', 'JPY(100)']
for step1 in cnt : 
    for step2 in range(40,80):
        data['{}_shift-{}'.format(step1,step2)] = data[step1].shift(step2)

# Nan Omit
data = data.dropna()

# %%
data
# Out:
#                USD      CAD      CHF      GBP      EUR  JPY(100)  \
# date
# 2010-04-27  1105.0  1103.72  1031.44  1709.21  1480.80   1175.59
# 2010-04-28  1121.1  1089.64  1017.79  1687.76  1458.38   1187.49
# 2010-04-29  1115.1  1107.77  1031.29  1701.29  1478.63   1190.76
# 2010-04-30  1108.2  1111.28  1031.25  1712.52  1479.32   1186.77
# 2010-05-03  1113.5  1090.83  1029.92  1697.11  1476.52   1178.44
# ...            ...      ...      ...      ...      ...       ...
# 2020-01-10  1160.0   888.34  1192.13  1516.00  1288.47   1059.60
# 2020-01-13  1161.1   888.85  1192.89  1514.48  1290.74   1059.93
# 2020-01-14  1155.7   885.39  1190.52  1501.25  1286.93   1051.35
# 2020-01-15  1153.1   882.76  1191.96  1501.34  1283.11   1048.42
# 2020-01-16  1158.8   888.45  1202.32  1511.36  1292.24   1054.37
#
#             USD_shift-40  USD_shift-41  USD_shift-42  USD_shift-43  ...  \
# date                                                                ...
# 2010-04-27        1153.4        1159.8        1156.5        1157.4  ...
# 2010-04-28        1146.3        1153.4        1159.8        1156.5  ...
# 2010-04-29        1143.8        1146.3        1153.4        1159.8  ...
# 2010-04-30        1142.3        1143.8        1146.3        1153.4  ...
# 2010-05-03        1134.2        1142.3        1143.8        1146.3  ...
# ...                  ...           ...           ...           ...  ...
# 2020-01-10        1163.5        1161.3        1156.1        1160.6  ...
# 2020-01-13        1167.6        1163.5        1161.3        1156.1  ...
# 2020-01-14        1170.4        1167.6        1163.5        1161.3  ...
# 2020-01-15        1166.3        1170.4        1167.6        1163.5  ...
# 2020-01-16        1164.5        1166.3        1170.4        1167.6  ...
#
#             JPY(100)_shift-70  JPY(100)_shift-71  JPY(100)_shift-72  \
# date
# 2010-04-27            1230.24            1232.05            1234.23
# 2010-04-28            1236.80            1230.24            1232.05
# 2010-04-29            1243.13            1236.80            1230.24
# 2010-04-30            1234.21            1243.13            1236.80
# 2010-05-03            1240.88            1234.21            1243.13
# ...                       ...                ...                ...
# 2020-01-10            1113.40            1112.13            1112.32
# 2020-01-13            1109.70            1113.40            1112.13
# 2020-01-14            1112.17            1109.70            1113.40
# 2020-01-15            1126.37            1112.17            1109.70
# 2020-01-16            1120.52            1126.37            1112.17
#
#             JPY(100)_shift-73  JPY(100)_shift-74  JPY(100)_shift-75  \
# date
# 2010-04-27            1216.58            1223.96            1211.91
# 2010-04-28            1234.23            1216.58            1223.96
# 2010-04-29            1232.05            1234.23            1216.58
# 2010-04-30            1230.24            1232.05            1234.23
# 2010-05-03            1236.80            1230.24            1232.05
# ...                       ...                ...                ...
# 2020-01-10            1114.59            1109.40            1106.46
# 2020-01-13            1112.32            1114.59            1109.40
# 2020-01-14            1112.13            1112.32            1114.59
# 2020-01-15            1113.40            1112.13            1112.32
# 2020-01-16            1109.70            1113.40            1112.13
#
#             JPY(100)_shift-76  JPY(100)_shift-77  JPY(100)_shift-78  \
# date
# 2010-04-27            1232.35            1248.35            1250.96
# 2010-04-28            1211.91            1232.35            1248.35
# 2010-04-29            1223.96            1211.91            1232.35
# 2010-04-30            1216.58            1223.96            1211.91
# 2010-05-03            1234.23            1216.58            1223.96
# ...                       ...                ...                ...
# 2020-01-10            1106.22            1098.15            1099.16
# 2020-01-13            1106.46            1106.22            1098.15
# 2020-01-14            1109.40            1106.46            1106.22
# 2020-01-15            1114.59            1109.40            1106.46
# 2020-01-16            1112.32            1114.59            1109.40
#
#             JPY(100)_shift-79
# date
# 2010-04-27            1256.50
# 2010-04-28            1250.96
# 2010-04-29            1248.35
# 2010-04-30            1232.35
# 2010-05-03            1211.91
# ...                       ...
# 2020-01-10            1095.13
# 2020-01-13            1099.16
# 2020-01-14            1098.15
# 2020-01-15            1106.22
# 2020-01-16            1106.46
#
# [2406 rows x 246 columns]

# %%
# X, y
X = data[data.columns[6:]]
y = data[data.columns[0]]

# %%
# MinMaxScaler
from sklearn.preprocessing import MinMaxScaler
sc_X = MinMaxScaler()
X = sc_X.fit_transform(X)
sc_y = MinMaxScaler()
y = sc_y.fit_transform(y.values.reshape(-1,1))

# %%
# Train Validation Test Split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=1234)
X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size=0.2, random_state=1234)

# %%
# Data Size
print('Train Set Size : {:,} obs' .format(len(X_train)))
print('Valid Set Size : {:,} obs' .format(len(X_valid)))
print('Test Set Size : {:,} obs' .format(len(X_test)))
# Out:
# Train Set Size : 1,732 obs
# Valid Set Size : 433 obs
# Test Set Size : 241 obs

# %%
# Sklearn Linear Regression
from sklearn.linear_model import LinearRegression
reg = LinearRegression().fit(X_train, y_train)

# %%
# Score
print("Train Score : {}" .format(reg.score(X_train, y_train)))
print("Valid Score : {}" .format(reg.score(X_valid, y_valid)))
print("Test Score : {}" .format(reg.score(X_test, y_test)))
# Out:
# Train Score : 0.6082421670081821
# Valid Score : 0.4743108692677365
# Test Score : 0.4014392827719351

# %%
# RMSE
from sklearn.metrics import mean_squared_error
pred_train = reg.predict(X_train)
print("Train rmse : {}" .format(mean_squared_error(y_train, pred_train)**0.5))
pred_valid = reg.predict(X_valid)
print("Valid rmse : {}" .format(mean_squared_error(y_valid, pred_valid)**0.5))
pred_test = reg.predict(X_test)
print("Test rmse : {}" .format(mean_squared_error(y_test, pred_test)**0.5))
# Out:
# Train rmse : 0.11066958771856075
# Valid rmse : 0.12777396731140264
# Test rmse : 0.14534534181023806

# %%
# Data Reverse
y_test_origin = sc_y.inverse_transform(y_test)
y_pred_origin = sc_y.inverse_transform(pred_test)

# Test Data
test = np.array([y_test_origin.reshape(-1), y_pred_origin.reshape(-1)]).transpose()
test = pd.DataFrame(test, columns = ['y_test', 'y_pred'])

# %%
# Pred vs True Visualization
plt.figure(figsize = (16,6))
sns.lineplot(data = test, linewidth = 2.5)
plt.show()
