# %%
# Library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Warnings
import warnings
warnings.filterwarnings(action='ignore')

# %%
# Data Loading
data = pd.read_csv('./data/DAILY_DATA.csv')
data = data[['date', 'USD', 'CAD', 'CHF', 'GBP', 'EUR', 'JPY(100)']].set_index('date')

# %%
data
# Out:
#                USD      CAD      CHF      GBP      EUR  JPY(100)
# date
# 2010-01-04  1161.0  1110.15  1128.17  1883.46  1673.46   1256.50
# 2010-01-05  1147.3  1109.76  1122.31  1860.44  1665.97   1250.96
# 2010-01-06  1141.4  1101.19  1106.67  1829.39  1643.96   1248.35
# 2010-01-07  1132.0  1102.69  1107.41  1822.54  1639.52   1232.35
# 2010-01-08  1134.1  1095.51  1095.46  1804.73  1621.38   1211.91
# ...            ...      ...      ...      ...      ...       ...
# 2020-01-10  1160.0   888.34  1192.13  1516.00  1288.47   1059.60
# 2020-01-13  1161.1   888.85  1192.89  1514.48  1290.74   1059.93
# 2020-01-14  1155.7   885.39  1190.52  1501.25  1286.93   1051.35
# 2020-01-15  1153.1   882.76  1191.96  1501.34  1283.11   1048.42
# 2020-01-16  1158.8   888.45  1202.32  1511.36  1292.24   1054.37
#
# [2485 rows x 6 columns]

# %%
# Data Shfit 생성    
cnt = ['USD', 'CAD', 'CHF', 'GBP', 'EUR', 'JPY(100)']
for step1 in cnt : 
    for step2 in range(10,20):
        data['{}_shift-{}'.format(step1,step2)] = data[step1].shift(step2)

# Nan Omit
data = data.dropna()

# %%
data
# Out:
#                USD      CAD      CHF      GBP      EUR  JPY(100)  \
# date
# 2010-01-29  1159.1  1084.13  1098.60  1864.91  1614.59   1287.00
# 2010-02-01  1160.5  1082.81  1090.87  1845.46  1605.43   1284.13
# 2010-02-02  1158.0  1100.92  1105.61  1864.22  1626.98   1287.26
# 2010-02-03  1151.6  1096.87  1099.57  1853.43  1620.20   1283.30
# 2010-02-04  1153.3  1084.63  1088.32  1833.73  1600.58   1267.20
# ...            ...      ...      ...      ...      ...       ...
# 2020-01-10  1160.0   888.34  1192.13  1516.00  1288.47   1059.60
# 2020-01-13  1161.1   888.85  1192.89  1514.48  1290.74   1059.93
# 2020-01-14  1155.7   885.39  1190.52  1501.25  1286.93   1051.35
# 2020-01-15  1153.1   882.76  1191.96  1501.34  1283.11   1048.42
# 2020-01-16  1158.8   888.45  1202.32  1511.36  1292.24   1054.37
#
#             USD_shift-10  USD_shift-11  USD_shift-12  USD_shift-13  ...  \
# date                                                                ...
# 2010-01-29        1122.2        1123.1        1127.0        1123.3  ...
# 2010-02-01        1128.4        1122.2        1123.1        1127.0  ...
# 2010-02-02        1123.4        1128.4        1122.2        1123.1  ...
# 2010-02-03        1128.0        1123.4        1128.4        1122.2  ...
# 2010-02-04        1137.9        1128.0        1123.4        1128.4  ...
# ...                  ...           ...           ...           ...  ...
# 2020-01-10        1163.7        1161.7        1162.6        1164.5  ...
# 2020-01-13        1161.2        1163.7        1161.7        1162.6  ...
# 2020-01-14        1160.9        1161.2        1163.7        1161.7  ...
# 2020-01-15        1157.8        1160.9        1161.2        1163.7  ...
# 2020-01-16        1157.8        1157.8        1160.9        1161.2  ...
#
#             JPY(100)_shift-10  JPY(100)_shift-11  JPY(100)_shift-12  \
# date
# 2010-01-29            1230.24            1232.05            1234.23
# 2010-02-01            1236.80            1230.24            1232.05
# 2010-02-02            1243.13            1236.80            1230.24
# 2010-02-03            1234.21            1243.13            1236.80
# 2010-02-04            1240.88            1234.21            1243.13
# ...                       ...                ...                ...
# 2020-01-10            1063.76            1061.98            1061.98
# 2020-01-13            1059.92            1063.76            1061.98
# 2020-01-14            1060.72            1059.92            1063.76
# 2020-01-15            1063.47            1060.72            1059.92
# 2020-01-16            1065.67            1063.47            1060.72
#
#             JPY(100)_shift-13  JPY(100)_shift-14  JPY(100)_shift-15  \
# date
# 2010-01-29            1216.58            1223.96            1211.91
# 2010-02-01            1234.23            1216.58            1223.96
# 2010-02-02            1232.05            1234.23            1216.58
# 2010-02-03            1230.24            1232.05            1234.23
# 2010-02-04            1236.80            1230.24            1232.05
# ...                       ...                ...                ...
# 2020-01-10            1064.78            1063.57            1065.33
# 2020-01-13            1061.98            1064.78            1063.57
# 2020-01-14            1061.98            1061.98            1064.78
# 2020-01-15            1063.76            1061.98            1061.98
# 2020-01-16            1059.92            1063.76            1061.98
#
#             JPY(100)_shift-16  JPY(100)_shift-17  JPY(100)_shift-18  \
# date
# 2010-01-29            1232.35            1248.35            1250.96
# 2010-02-01            1211.91            1232.35            1248.35
# 2010-02-02            1223.96            1211.91            1232.35
# 2010-02-03            1216.58            1223.96            1211.91
# 2010-02-04            1234.23            1216.58            1223.96
# ...                       ...                ...                ...
# 2020-01-10            1070.16            1071.46            1085.23
# 2020-01-13            1065.33            1070.16            1071.46
# 2020-01-14            1063.57            1065.33            1070.16
# 2020-01-15            1064.78            1063.57            1065.33
# 2020-01-16            1061.98            1064.78            1063.57
#
#             JPY(100)_shift-19
# date
# 2010-01-29            1256.50
# 2010-02-01            1250.96
# 2010-02-02            1248.35
# 2010-02-03            1232.35
# 2010-02-04            1211.91
# ...                       ...
# 2020-01-10            1099.36
# 2020-01-13            1085.23
# 2020-01-14            1071.46
# 2020-01-15            1070.16
# 2020-01-16            1065.33
#
# [2466 rows x 66 columns]

# %%
# X, y
X = data[data.columns[6:]]
y = data[data.columns[0]]

# %%
# MinMaxScaler
from sklearn.preprocessing import MinMaxScaler
sc_X = MinMaxScaler()
X = sc_X.fit_transform(X)
sc_y = MinMaxScaler()
y = sc_y.fit_transform(y.values.reshape(-1,1))

# %%
# Train Validation Test Split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=1234)
X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size=0.2, random_state=1234)

# %%
# Data Size
print('Train Set Size : {:,} obs' .format(len(X_train)))
print('Valid Set Size : {:,} obs' .format(len(X_valid)))
print('Test Set Size : {:,} obs' .format(len(X_test)))
# Out:
# Train Set Size : 1,775 obs
# Valid Set Size : 444 obs
# Test Set Size : 247 obs

# %%
# Sklearn Linear Regression
from sklearn.linear_model import LinearRegression
reg = LinearRegression().fit(X_train, y_train)

# %%
# Score
print("Train Score : {}" .format(reg.score(X_train, y_train)))
print("Valid Score : {}" .format(reg.score(X_valid, y_valid)))
print("Test Score : {}" .format(reg.score(X_test, y_test)))
# Out:
# Train Score : 0.8466431797334981
# Valid Score : 0.7998751853772778
# Test Score : 0.8206900509710912

# %%
# RMSE
from sklearn.metrics import mean_squared_error
pred_train = reg.predict(X_train)
print("Train rmse : {}" .format(mean_squared_error(y_train, pred_train)**0.5))
pred_valid = reg.predict(X_valid)
print("Valid rmse : {}" .format(mean_squared_error(y_valid, pred_valid)**0.5))
pred_test = reg.predict(X_test)
print("Test rmse : {}" .format(mean_squared_error(y_test, pred_test)**0.5))
# Out:
# Train rmse : 0.06928436529424999
# Valid rmse : 0.08054608767403759
# Test rmse : 0.07003673376084832

# %%
# Data Reverse
y_test_origin = sc_y.inverse_transform(y_test)
y_pred_origin = sc_y.inverse_transform(pred_test)

# Test Data
test = np.array([y_test_origin.reshape(-1), y_pred_origin.reshape(-1)]).transpose()
test = pd.DataFrame(test, columns = ['y_test', 'y_pred'])

# %%
# Pred vs True Visualization
plt.figure(figsize = (16,6))
sns.lineplot(data = test, linewidth = 2.5)
plt.show()
